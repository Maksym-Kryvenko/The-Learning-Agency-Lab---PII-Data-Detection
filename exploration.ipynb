# %%
text='''
Look for data to help you address the question. Governments are good
sources because data from public research is often freely available. Good
places to start include http://www.data.gov/, and http://www.science.
gov/, and in the United Kingdom, http://data.gov.uk/.
Two of my favorite data sets are the General Social Survey at http://www3.norc.org/gss+website/, 
and the European Social Survey at http://www.europeansocialsurvey.org/.
'''

# %%
import spacy

# extend "blank" pipeline with extra 'tok2vec', 'tagger', 'parser', 'attribute_ruler', 'lemmatizer', 'ner'
# !python -m spacy download en_core_web_sm
nlp = spacy.load("en_core_web_sm")
# Out:
# Collecting en-core-web-sm==3.7.1
#   Using cached https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.7.1/en_core_web_sm-3.7.1-py3-none-any.whl (12.8 MB)
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in d:\learning_py\kaggle\autocorrect-and-autocomplete-nlp\autocorrect_venv\lib\site-packages (from en-core-web-sm==3.7.1) (3.7.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in d:\learning_py\kaggle\autocorrect-and-autocomplete-nlp\autocorrect_venv\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in d:\learning_py\kaggle\autocorrect-and-autocomplete-nlp\autocorrect_venv\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in d:\learning_py\kaggle\autocorrect-and-autocomplete-nlp\autocorrect_venv\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in d:\learning_py\kaggle\autocorrect-and-autocomplete-nlp\autocorrect_venv\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in d:\learning_py\kaggle\autocorrect-and-autocomplete-nlp\autocorrect_venv\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in d:\learning_py\kaggle\autocorrect-and-autocomplete-nlp\autocorrect_venv\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in d:\learning_py\kaggle\autocorrect-and-autocomplete-nlp\autocorrect_venv\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in d:\learning_py\kaggle\autocorrect-and-autocomplete-nlp\autocorrect_venv\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in d:\learning_py\kaggle\autocorrect-and-autocomplete-nlp\autocorrect_venv\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in d:\learning_py\kaggle\autocorrect-and-autocomplete-nlp\autocorrect_venv\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in d:\learning_py\kaggle\autocorrect-and-autocomplete-nlp\autocorrect_venv\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.9.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in d:\learning_py\kaggle\autocorrect-and-autocomplete-nlp\autocorrect_venv\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in d:\learning_py\kaggle\autocorrect-and-autocomplete-nlp\autocorrect_venv\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.66.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in d:\learning_py\kaggle\autocorrect-and-autocomplete-nlp\autocorrect_venv\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in d:\learning_py\kaggle\autocorrect-and-autocomplete-nlp\autocorrect_venv\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.6.2)
# Requirement already satisfied: jinja2 in d:\learning_py\kaggle\autocorrect-and-autocomplete-nlp\autocorrect_venv\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.1.3)
# Requirement already satisfied: setuptools in d:\learning_py\kaggle\autocorrect-and-autocomplete-nlp\autocorrect_venv\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (65.5.0)
# Requirement already satisfied: packaging>=20.0 in d:\learning_py\kaggle\autocorrect-and-autocomplete-nlp\autocorrect_venv\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (23.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in d:\learning_py\kaggle\autocorrect-and-autocomplete-nlp\autocorrect_venv\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.3.0)
# Requirement already satisfied: numpy>=1.19.0 in d:\learning_py\kaggle\autocorrect-and-autocomplete-nlp\autocorrect_venv\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.26.4)
# Requirement already satisfied: annotated-types>=0.4.0 in d:\learning_py\kaggle\autocorrect-and-autocomplete-nlp\autocorrect_venv\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in d:\learning_py\kaggle\autocorrect-and-autocomplete-nlp\autocorrect_venv\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.16.3)
# Requirement already satisfied: typing-extensions>=4.6.1 in d:\learning_py\kaggle\autocorrect-and-autocomplete-nlp\autocorrect_venv\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\learning_py\kaggle\autocorrect-and-autocomplete-nlp\autocorrect_venv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in d:\learning_py\kaggle\autocorrect-and-autocomplete-nlp\autocorrect_venv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\learning_py\kaggle\autocorrect-and-autocomplete-nlp\autocorrect_venv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in d:\learning_py\kaggle\autocorrect-and-autocomplete-nlp\autocorrect_venv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2024.2.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in d:\learning_py\kaggle\autocorrect-and-autocomplete-nlp\autocorrect_venv\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in d:\learning_py\kaggle\autocorrect-and-autocomplete-nlp\autocorrect_venv\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.1.4)
# Requirement already satisfied: colorama in d:\learning_py\kaggle\autocorrect-and-autocomplete-nlp\autocorrect_venv\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in d:\learning_py\kaggle\autocorrect-and-autocomplete-nlp\autocorrect_venv\lib\site-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in d:\learning_py\kaggle\autocorrect-and-autocomplete-nlp\autocorrect_venv\lib\site-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\learning_py\kaggle\autocorrect-and-autocomplete-nlp\autocorrect_venv\lib\site-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.1.5)
# Installing collected packages: en-core-web-sm
# Successfully installed en-core-web-sm-3.7.1
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
nlp.pipe_names
# Out:
# ['tok2vec', 'tagger', 'parser', 'attribute_ruler', 'lemmatizer', 'ner']

# %%
nlp = spacy.blank('en')

doc = nlp(text)
# Out:
# '\nLook for data to help you address the question. Governments are good\nsources because data from public research is often freely available. Good\nplaces to start include http://www.data.gov/, and http://www.science.\ngov/, and in the United Kingdom, http://data.gov.uk/.\nTwo of my favorite data sets are the General Social Survey at http://www3.norc.org/gss+website/, \nand the European Social Survey at http://www.europeansocialsurvey.org/.\n'

# %%
for sentance in doc:
    if sentance.like_url:
        print(sentance)
# Out:
# http://www.data.gov/
# http://www.science
# http://data.gov.uk/.
# http://www3.norc.org/gss+website/
# http://www.europeansocialsurvey.org/.

# %%
transactions = "Tony gave two $ to Peter, Bruce gave 500 € to Steve"

doc = nlp(transactions)

# %%
for word in doc:
    if word.like_num and doc[word.i+1].is_currency:
        print(word.text, doc[word.i+1].text)
# Out:
# two $
# 500 €

# %%
doc = nlp(text)

for token in doc:
    print(token, "|", token.pos_, "|", token.lemma_)
# Out:
#  | SPACE |
#
# Look | VERB | look
# for | ADP | for
# data | NOUN | datum
# to | PART | to
# help | VERB | help
# you | PRON | you
# address | VERB | address
# the | DET | the
# question | NOUN | question
# . | PUNCT | .
# Governments | NOUN | government
# are | AUX | be
# good | ADJ | good
#
#  | SPACE |
#
# sources | NOUN | source
# because | SCONJ | because
# data | NOUN | datum
# from | ADP | from
# public | ADJ | public
# research | NOUN | research
# is | AUX | be
# often | ADV | often
# freely | ADV | freely
# available | ADJ | available
# . | PUNCT | .
# Good | ADJ | good
#
#  | SPACE |
#
# places | NOUN | place
# to | PART | to
# start | VERB | start
# include | VERB | include
# http://www.data.gov/ | INTJ | http://www.data.gov/
# , | PUNCT | ,
# and | CCONJ | and
# http://www.science | PROPN | http://www.science
# . | PUNCT | .
#
#  | SPACE |
#
# gov/ | X | gov/
# , | PUNCT | ,
# and | CCONJ | and
# in | ADP | in
# the | DET | the
# United | PROPN | United
# Kingdom | PROPN | Kingdom
# , | PUNCT | ,
# http://data.gov.uk/. | PROPN | http://data.gov.uk/.
#
#  | SPACE |
#
# Two | NUM | two
# of | ADP | of
# my | PRON | my
# favorite | ADJ | favorite
# data | NOUN | data
# sets | NOUN | set
# are | AUX | be
# the | DET | the
# General | PROPN | General
# Social | PROPN | Social
# Survey | PROPN | Survey
# at | ADP | at
# http://www3.norc.org/gss+website/ | PROPN | http://www3.norc.org/gss+website/
# , | PUNCT | ,
#
#  | SPACE |
#
# and | CCONJ | and
# the | DET | the
# European | PROPN | European
# Social | PROPN | Social
# Survey | PROPN | Survey
# at | ADP | at
# http://www.europeansocialsurvey.org/. | PROPN | http://www.europeansocialsurvey.org/.
#
#  | SPACE |

# %%
for ent in doc.ents:
    print(ent, "|", ent.label_, "|", spacy.explain(ent.label_))
# Out:
# the United Kingdom | GPE | Countries, cities, states
# Two | CARDINAL | Numerals that do not fall under another type
# the General Social Survey | ORG | Companies, agencies, institutions, etc.
# the European Social Survey | ORG | Companies, agencies, institutions, etc.

# %%
from spacy import displacy

displacy.render(doc, style="ent")
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr"><br>Look for data to help you address the question. Governments are good<br>sources because data from public research is often freely available. Good<br>places to start include http://www.data.gov/, and http://www.science.<br>gov/, and in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the United Kingdom
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , http://data.gov.uk/.<br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Two
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  of my favorite data sets are
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the General Social Survey
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  at http://www3.norc.org/gss+website/, <br>and
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the European Social Survey
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  at http://www.europeansocialsurvey.org/.<br></div></span>

# %%
import nltk

# %%
from nltk.stem import PorterStemmer

stemmer = PorterStemmer()

# %%
sample = nltk.sent_tokenize(text)[1].split()

# %%
sample
# Out:
# ['Governments',
#  'are',
#  'good',
#  'sources',
#  'because',
#  'data',
#  'from',
#  'public',
#  'research',
#  'is',
#  'often',
#  'freely',
#  'available.']

# %%
for word in sample:
    print(word, "|", stemmer.stem(word))
# Out:
# Governments | govern
# are | are
# good | good
# sources | sourc
# because | becaus
# data | data
# from | from
# public | public
# research | research
# is | is
# often | often
# freely | freeli
# available. | available.

# %%
nlp = spacy.load("en_core_web_sm")

doc = nlp(' '.join(sample))

for token in doc:
    print(token, "|", token.lemma_)
# Out:
# Governments | government
# are | be
# good | good
# sources | source
# because | because
# data | datum
# from | from
# public | public
# research | research
# is | be
# often | often
# freely | freely
# available | available
# . | .

# %%
# create custom rule for lemmatization - replace "bro" and "brah" with "brother"
ar = nlp.get_pipe('attribute_ruler')
ar.add([[{"TEXT": "bro"}], [{"TEXT": "brah"}]], 
         {"LEMMA": "brother"})

# %%
doc = nlp("Bro, you wanna go? Brah, don't say no! I am exhausted.")

for token in doc:
    print(token, token.lemma_, sep='|')
# Out:
# Bro|brother
# ,|,
# you|you
# wanna|wanna
# go|go
# ?|?
# Brah|brother
# ,|,
# do|do
# n't|not
# say|say
# no|no
# !|!
# I|I
# am|be
# exhausted|exhaust
# .|.

# %%
doc = nlp("""Inflation rose again in April, continuing a climb that has pushed consumers to the brink and is threatening the economic expansion, the Bureau of Labor Statistics reported Wednesday.

The consumer price index, a broad-based measure of prices for goods and services, increased 8.3% from a year ago, higher than the Dow Jones estimate for an 8.1% gain. That represented a slight ease from March’s peak but was still close to the highest level since the summer of 1982.

Removing volatile food and energy prices, so-called core CPI still rose 6.2%, against expectations for a 6% gain, clouding hopes that inflation had peaked in March.

The month-over-month gains also were higher than expectations — 0.3% on headline CPI versus the 0.2% estimate and a 0.6% increase for core, against the outlook for a 0.4% gain.

The price gains also meant that workers continued to lose ground. Real wages adjusted for inflation decreased 0.1% on the month despite a nominal increase of 0.3% in average hourly earnings. Over the past year, real earnings have dropped 2.6% even though average hourly earnings are up 5.5%.

Inflation has been the single biggest threat to a recovery that began early in the Covid pandemic and saw the economy in 2021 stage its biggest single-year growth level since 1984. Rising prices at the pump and in grocery stores have been one problem, but inflation has spread beyond those two areas into housing, auto sales and a host of other areas.

Federal Reserve officials have responded to the problem with two interest rate hikes so far this year and pledges of more until inflation comes down to the central bank’s 2% goal. However, Wednesday’s data shows that the Fed has a big job ahead.

Credits: cnbc.com""")

# %%
for token in doc:
    #if token.pos_ == "NOUN":
        print(token," | ", token.pos_, " | ", spacy.explain(token.pos_), " | ", token.tag_, " | ", spacy.explain(token.tag_))
# Out:
# Inflation  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# rose  |  VERB  |  verb  |  VBD  |  verb, past tense
# again  |  ADV  |  adverb  |  RB  |  adverb
# in  |  ADP  |  adposition  |  IN  |  conjunction, subordinating or preposition
# April  |  PROPN  |  proper noun  |  NNP  |  noun, proper singular
# ,  |  PUNCT  |  punctuation  |  ,  |  punctuation mark, comma
# continuing  |  VERB  |  verb  |  VBG  |  verb, gerund or present participle
# a  |  DET  |  determiner  |  DT  |  determiner
# climb  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# that  |  PRON  |  pronoun  |  WDT  |  wh-determiner
# has  |  AUX  |  auxiliary  |  VBZ  |  verb, 3rd person singular present
# pushed  |  VERB  |  verb  |  VBN  |  verb, past participle
# consumers  |  NOUN  |  noun  |  NNS  |  noun, plural
# to  |  ADP  |  adposition  |  IN  |  conjunction, subordinating or preposition
# the  |  DET  |  determiner  |  DT  |  determiner
# brink  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# and  |  CCONJ  |  coordinating conjunction  |  CC  |  conjunction, coordinating
# is  |  AUX  |  auxiliary  |  VBZ  |  verb, 3rd person singular present
# threatening  |  VERB  |  verb  |  VBG  |  verb, gerund or present participle
# the  |  DET  |  determiner  |  DT  |  determiner
# economic  |  ADJ  |  adjective  |  JJ  |  adjective (English), other noun-modifier (Chinese)
# expansion  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# ,  |  PUNCT  |  punctuation  |  ,  |  punctuation mark, comma
# the  |  DET  |  determiner  |  DT  |  determiner
# Bureau  |  PROPN  |  proper noun  |  NNP  |  noun, proper singular
# of  |  ADP  |  adposition  |  IN  |  conjunction, subordinating or preposition
# Labor  |  PROPN  |  proper noun  |  NNP  |  noun, proper singular
# Statistics  |  PROPN  |  proper noun  |  NNPS  |  noun, proper plural
# reported  |  VERB  |  verb  |  VBD  |  verb, past tense
# Wednesday  |  PROPN  |  proper noun  |  NNP  |  noun, proper singular
# .  |  PUNCT  |  punctuation  |  .  |  punctuation mark, sentence closer
#
#
#   |  SPACE  |  space  |  _SP  |  whitespace
# The  |  DET  |  determiner  |  DT  |  determiner
# consumer  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# price  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# index  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# ,  |  PUNCT  |  punctuation  |  ,  |  punctuation mark, comma
# a  |  DET  |  determiner  |  DT  |  determiner
# broad  |  ADV  |  adverb  |  RB  |  adverb
# -  |  PUNCT  |  punctuation  |  HYPH  |  punctuation mark, hyphen
# based  |  VERB  |  verb  |  VBN  |  verb, past participle
# measure  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# of  |  ADP  |  adposition  |  IN  |  conjunction, subordinating or preposition
# prices  |  NOUN  |  noun  |  NNS  |  noun, plural
# for  |  ADP  |  adposition  |  IN  |  conjunction, subordinating or preposition
# goods  |  NOUN  |  noun  |  NNS  |  noun, plural
# and  |  CCONJ  |  coordinating conjunction  |  CC  |  conjunction, coordinating
# services  |  NOUN  |  noun  |  NNS  |  noun, plural
# ,  |  PUNCT  |  punctuation  |  ,  |  punctuation mark, comma
# increased  |  VERB  |  verb  |  VBD  |  verb, past tense
# 8.3  |  NUM  |  numeral  |  CD  |  cardinal number
# %  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# from  |  ADP  |  adposition  |  IN  |  conjunction, subordinating or preposition
# a  |  DET  |  determiner  |  DT  |  determiner
# year  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# ago  |  ADV  |  adverb  |  RB  |  adverb
# ,  |  PUNCT  |  punctuation  |  ,  |  punctuation mark, comma
# higher  |  ADJ  |  adjective  |  JJR  |  adjective, comparative
# than  |  ADP  |  adposition  |  IN  |  conjunction, subordinating or preposition
# the  |  DET  |  determiner  |  DT  |  determiner
# Dow  |  PROPN  |  proper noun  |  NNP  |  noun, proper singular
# Jones  |  PROPN  |  proper noun  |  NNP  |  noun, proper singular
# estimate  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# for  |  ADP  |  adposition  |  IN  |  conjunction, subordinating or preposition
# an  |  DET  |  determiner  |  DT  |  determiner
# 8.1  |  NUM  |  numeral  |  CD  |  cardinal number
# %  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# gain  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# .  |  PUNCT  |  punctuation  |  .  |  punctuation mark, sentence closer
# That  |  PRON  |  pronoun  |  DT  |  determiner
# represented  |  VERB  |  verb  |  VBD  |  verb, past tense
# a  |  DET  |  determiner  |  DT  |  determiner
# slight  |  ADJ  |  adjective  |  JJ  |  adjective (English), other noun-modifier (Chinese)
# ease  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# from  |  ADP  |  adposition  |  IN  |  conjunction, subordinating or preposition
# March  |  PROPN  |  proper noun  |  NNP  |  noun, proper singular
# ’s  |  PART  |  particle  |  POS  |  possessive ending
# peak  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# but  |  CCONJ  |  coordinating conjunction  |  CC  |  conjunction, coordinating
# was  |  AUX  |  auxiliary  |  VBD  |  verb, past tense
# still  |  ADV  |  adverb  |  RB  |  adverb
# close  |  ADJ  |  adjective  |  JJ  |  adjective (English), other noun-modifier (Chinese)
# to  |  ADP  |  adposition  |  IN  |  conjunction, subordinating or preposition
# the  |  DET  |  determiner  |  DT  |  determiner
# highest  |  ADJ  |  adjective  |  JJS  |  adjective, superlative
# level  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# since  |  SCONJ  |  subordinating conjunction  |  IN  |  conjunction, subordinating or preposition
# the  |  DET  |  determiner  |  DT  |  determiner
# summer  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# of  |  ADP  |  adposition  |  IN  |  conjunction, subordinating or preposition
# 1982  |  NUM  |  numeral  |  CD  |  cardinal number
# .  |  PUNCT  |  punctuation  |  .  |  punctuation mark, sentence closer
#
#
#   |  SPACE  |  space  |  _SP  |  whitespace
# Removing  |  VERB  |  verb  |  VBG  |  verb, gerund or present participle
# volatile  |  ADJ  |  adjective  |  JJ  |  adjective (English), other noun-modifier (Chinese)
# food  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# and  |  CCONJ  |  coordinating conjunction  |  CC  |  conjunction, coordinating
# energy  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# prices  |  NOUN  |  noun  |  NNS  |  noun, plural
# ,  |  PUNCT  |  punctuation  |  ,  |  punctuation mark, comma
# so  |  ADV  |  adverb  |  RB  |  adverb
# -  |  PUNCT  |  punctuation  |  HYPH  |  punctuation mark, hyphen
# called  |  VERB  |  verb  |  VBN  |  verb, past participle
# core  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# CPI  |  PROPN  |  proper noun  |  NNP  |  noun, proper singular
# still  |  ADV  |  adverb  |  RB  |  adverb
# rose  |  VERB  |  verb  |  VBD  |  verb, past tense
# 6.2  |  NUM  |  numeral  |  CD  |  cardinal number
# %  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# ,  |  PUNCT  |  punctuation  |  ,  |  punctuation mark, comma
# against  |  ADP  |  adposition  |  IN  |  conjunction, subordinating or preposition
# expectations  |  NOUN  |  noun  |  NNS  |  noun, plural
# for  |  ADP  |  adposition  |  IN  |  conjunction, subordinating or preposition
# a  |  DET  |  determiner  |  DT  |  determiner
# 6  |  NUM  |  numeral  |  CD  |  cardinal number
# %  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# gain  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# ,  |  PUNCT  |  punctuation  |  ,  |  punctuation mark, comma
# clouding  |  VERB  |  verb  |  VBG  |  verb, gerund or present participle
# hopes  |  NOUN  |  noun  |  NNS  |  noun, plural
# that  |  SCONJ  |  subordinating conjunction  |  IN  |  conjunction, subordinating or preposition
# inflation  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# had  |  AUX  |  auxiliary  |  VBD  |  verb, past tense
# peaked  |  VERB  |  verb  |  VBN  |  verb, past participle
# in  |  ADP  |  adposition  |  IN  |  conjunction, subordinating or preposition
# March  |  PROPN  |  proper noun  |  NNP  |  noun, proper singular
# .  |  PUNCT  |  punctuation  |  .  |  punctuation mark, sentence closer
#
#
#   |  SPACE  |  space  |  _SP  |  whitespace
# The  |  DET  |  determiner  |  DT  |  determiner
# month  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# -  |  PUNCT  |  punctuation  |  HYPH  |  punctuation mark, hyphen
# over  |  ADP  |  adposition  |  IN  |  conjunction, subordinating or preposition
# -  |  PUNCT  |  punctuation  |  HYPH  |  punctuation mark, hyphen
# month  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# gains  |  NOUN  |  noun  |  NNS  |  noun, plural
# also  |  ADV  |  adverb  |  RB  |  adverb
# were  |  AUX  |  auxiliary  |  VBD  |  verb, past tense
# higher  |  ADJ  |  adjective  |  JJR  |  adjective, comparative
# than  |  ADP  |  adposition  |  IN  |  conjunction, subordinating or preposition
# expectations  |  NOUN  |  noun  |  NNS  |  noun, plural
# —  |  PUNCT  |  punctuation  |  :  |  punctuation mark, colon or ellipsis
# 0.3  |  NUM  |  numeral  |  CD  |  cardinal number
# %  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# on  |  ADP  |  adposition  |  IN  |  conjunction, subordinating or preposition
# headline  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# CPI  |  PROPN  |  proper noun  |  NNP  |  noun, proper singular
# versus  |  ADP  |  adposition  |  IN  |  conjunction, subordinating or preposition
# the  |  DET  |  determiner  |  DT  |  determiner
# 0.2  |  NUM  |  numeral  |  CD  |  cardinal number
# %  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# estimate  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# and  |  CCONJ  |  coordinating conjunction  |  CC  |  conjunction, coordinating
# a  |  DET  |  determiner  |  DT  |  determiner
# 0.6  |  NUM  |  numeral  |  CD  |  cardinal number
# %  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# increase  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# for  |  ADP  |  adposition  |  IN  |  conjunction, subordinating or preposition
# core  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# ,  |  PUNCT  |  punctuation  |  ,  |  punctuation mark, comma
# against  |  ADP  |  adposition  |  IN  |  conjunction, subordinating or preposition
# the  |  DET  |  determiner  |  DT  |  determiner
# outlook  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# for  |  ADP  |  adposition  |  IN  |  conjunction, subordinating or preposition
# a  |  DET  |  determiner  |  DT  |  determiner
# 0.4  |  NUM  |  numeral  |  CD  |  cardinal number
# %  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# gain  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# .  |  PUNCT  |  punctuation  |  .  |  punctuation mark, sentence closer
#
#
#   |  SPACE  |  space  |  _SP  |  whitespace
# The  |  DET  |  determiner  |  DT  |  determiner
# price  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# gains  |  NOUN  |  noun  |  NNS  |  noun, plural
# also  |  ADV  |  adverb  |  RB  |  adverb
# meant  |  VERB  |  verb  |  VBD  |  verb, past tense
# that  |  SCONJ  |  subordinating conjunction  |  IN  |  conjunction, subordinating or preposition
# workers  |  NOUN  |  noun  |  NNS  |  noun, plural
# continued  |  VERB  |  verb  |  VBD  |  verb, past tense
# to  |  PART  |  particle  |  TO  |  infinitival "to"
# lose  |  VERB  |  verb  |  VB  |  verb, base form
# ground  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# .  |  PUNCT  |  punctuation  |  .  |  punctuation mark, sentence closer
# Real  |  ADJ  |  adjective  |  JJ  |  adjective (English), other noun-modifier (Chinese)
# wages  |  NOUN  |  noun  |  NNS  |  noun, plural
# adjusted  |  VERB  |  verb  |  VBN  |  verb, past participle
# for  |  ADP  |  adposition  |  IN  |  conjunction, subordinating or preposition
# inflation  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# decreased  |  VERB  |  verb  |  VBD  |  verb, past tense
# 0.1  |  NUM  |  numeral  |  CD  |  cardinal number
# %  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# on  |  ADP  |  adposition  |  IN  |  conjunction, subordinating or preposition
# the  |  DET  |  determiner  |  DT  |  determiner
# month  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# despite  |  SCONJ  |  subordinating conjunction  |  IN  |  conjunction, subordinating or preposition
# a  |  DET  |  determiner  |  DT  |  determiner
# nominal  |  ADJ  |  adjective  |  JJ  |  adjective (English), other noun-modifier (Chinese)
# increase  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# of  |  ADP  |  adposition  |  IN  |  conjunction, subordinating or preposition
# 0.3  |  NUM  |  numeral  |  CD  |  cardinal number
# %  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# in  |  ADP  |  adposition  |  IN  |  conjunction, subordinating or preposition
# average  |  ADJ  |  adjective  |  JJ  |  adjective (English), other noun-modifier (Chinese)
# hourly  |  ADJ  |  adjective  |  JJ  |  adjective (English), other noun-modifier (Chinese)
# earnings  |  NOUN  |  noun  |  NNS  |  noun, plural
# .  |  PUNCT  |  punctuation  |  .  |  punctuation mark, sentence closer
# Over  |  ADP  |  adposition  |  IN  |  conjunction, subordinating or preposition
# the  |  DET  |  determiner  |  DT  |  determiner
# past  |  ADJ  |  adjective  |  JJ  |  adjective (English), other noun-modifier (Chinese)
# year  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# ,  |  PUNCT  |  punctuation  |  ,  |  punctuation mark, comma
# real  |  ADJ  |  adjective  |  JJ  |  adjective (English), other noun-modifier (Chinese)
# earnings  |  NOUN  |  noun  |  NNS  |  noun, plural
# have  |  AUX  |  auxiliary  |  VBP  |  verb, non-3rd person singular present
# dropped  |  VERB  |  verb  |  VBN  |  verb, past participle
# 2.6  |  NUM  |  numeral  |  CD  |  cardinal number
# %  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# even  |  ADV  |  adverb  |  RB  |  adverb
# though  |  SCONJ  |  subordinating conjunction  |  IN  |  conjunction, subordinating or preposition
# average  |  ADJ  |  adjective  |  JJ  |  adjective (English), other noun-modifier (Chinese)
# hourly  |  ADJ  |  adjective  |  JJ  |  adjective (English), other noun-modifier (Chinese)
# earnings  |  NOUN  |  noun  |  NNS  |  noun, plural
# are  |  AUX  |  auxiliary  |  VBP  |  verb, non-3rd person singular present
# up  |  ADV  |  adverb  |  RB  |  adverb
# 5.5  |  NUM  |  numeral  |  CD  |  cardinal number
# %  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# .  |  PUNCT  |  punctuation  |  .  |  punctuation mark, sentence closer
#
#
#   |  SPACE  |  space  |  _SP  |  whitespace
# Inflation  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# has  |  AUX  |  auxiliary  |  VBZ  |  verb, 3rd person singular present
# been  |  AUX  |  auxiliary  |  VBN  |  verb, past participle
# the  |  DET  |  determiner  |  DT  |  determiner
# single  |  ADJ  |  adjective  |  JJ  |  adjective (English), other noun-modifier (Chinese)
# biggest  |  ADJ  |  adjective  |  JJS  |  adjective, superlative
# threat  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# to  |  ADP  |  adposition  |  IN  |  conjunction, subordinating or preposition
# a  |  DET  |  determiner  |  DT  |  determiner
# recovery  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# that  |  PRON  |  pronoun  |  WDT  |  wh-determiner
# began  |  VERB  |  verb  |  VBD  |  verb, past tense
# early  |  ADV  |  adverb  |  RB  |  adverb
# in  |  ADP  |  adposition  |  IN  |  conjunction, subordinating or preposition
# the  |  DET  |  determiner  |  DT  |  determiner
# Covid  |  PROPN  |  proper noun  |  NNP  |  noun, proper singular
# pandemic  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# and  |  CCONJ  |  coordinating conjunction  |  CC  |  conjunction, coordinating
# saw  |  VERB  |  verb  |  VBD  |  verb, past tense
# the  |  DET  |  determiner  |  DT  |  determiner
# economy  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# in  |  ADP  |  adposition  |  IN  |  conjunction, subordinating or preposition
# 2021  |  NUM  |  numeral  |  CD  |  cardinal number
# stage  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# its  |  PRON  |  pronoun  |  PRP$  |  pronoun, possessive
# biggest  |  ADJ  |  adjective  |  JJS  |  adjective, superlative
# single  |  ADJ  |  adjective  |  JJ  |  adjective (English), other noun-modifier (Chinese)
# -  |  PUNCT  |  punctuation  |  HYPH  |  punctuation mark, hyphen
# year  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# growth  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# level  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# since  |  SCONJ  |  subordinating conjunction  |  IN  |  conjunction, subordinating or preposition
# 1984  |  NUM  |  numeral  |  CD  |  cardinal number
# .  |  PUNCT  |  punctuation  |  .  |  punctuation mark, sentence closer
# Rising  |  VERB  |  verb  |  VBG  |  verb, gerund or present participle
# prices  |  NOUN  |  noun  |  NNS  |  noun, plural
# at  |  ADP  |  adposition  |  IN  |  conjunction, subordinating or preposition
# the  |  DET  |  determiner  |  DT  |  determiner
# pump  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# and  |  CCONJ  |  coordinating conjunction  |  CC  |  conjunction, coordinating
# in  |  ADP  |  adposition  |  IN  |  conjunction, subordinating or preposition
# grocery  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# stores  |  NOUN  |  noun  |  NNS  |  noun, plural
# have  |  AUX  |  auxiliary  |  VBP  |  verb, non-3rd person singular present
# been  |  AUX  |  auxiliary  |  VBN  |  verb, past participle
# one  |  NUM  |  numeral  |  CD  |  cardinal number
# problem  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# ,  |  PUNCT  |  punctuation  |  ,  |  punctuation mark, comma
# but  |  CCONJ  |  coordinating conjunction  |  CC  |  conjunction, coordinating
# inflation  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# has  |  AUX  |  auxiliary  |  VBZ  |  verb, 3rd person singular present
# spread  |  VERB  |  verb  |  VBN  |  verb, past participle
# beyond  |  ADP  |  adposition  |  IN  |  conjunction, subordinating or preposition
# those  |  DET  |  determiner  |  DT  |  determiner
# two  |  NUM  |  numeral  |  CD  |  cardinal number
# areas  |  NOUN  |  noun  |  NNS  |  noun, plural
# into  |  ADP  |  adposition  |  IN  |  conjunction, subordinating or preposition
# housing  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# ,  |  PUNCT  |  punctuation  |  ,  |  punctuation mark, comma
# auto  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# sales  |  NOUN  |  noun  |  NNS  |  noun, plural
# and  |  CCONJ  |  coordinating conjunction  |  CC  |  conjunction, coordinating
# a  |  DET  |  determiner  |  DT  |  determiner
# host  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# of  |  ADP  |  adposition  |  IN  |  conjunction, subordinating or preposition
# other  |  ADJ  |  adjective  |  JJ  |  adjective (English), other noun-modifier (Chinese)
# areas  |  NOUN  |  noun  |  NNS  |  noun, plural
# .  |  PUNCT  |  punctuation  |  .  |  punctuation mark, sentence closer
#
#
#   |  SPACE  |  space  |  _SP  |  whitespace
# Federal  |  PROPN  |  proper noun  |  NNP  |  noun, proper singular
# Reserve  |  PROPN  |  proper noun  |  NNP  |  noun, proper singular
# officials  |  NOUN  |  noun  |  NNS  |  noun, plural
# have  |  AUX  |  auxiliary  |  VBP  |  verb, non-3rd person singular present
# responded  |  VERB  |  verb  |  VBN  |  verb, past participle
# to  |  ADP  |  adposition  |  IN  |  conjunction, subordinating or preposition
# the  |  DET  |  determiner  |  DT  |  determiner
# problem  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# with  |  ADP  |  adposition  |  IN  |  conjunction, subordinating or preposition
# two  |  NUM  |  numeral  |  CD  |  cardinal number
# interest  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# rate  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# hikes  |  NOUN  |  noun  |  NNS  |  noun, plural
# so  |  ADV  |  adverb  |  RB  |  adverb
# far  |  ADV  |  adverb  |  RB  |  adverb
# this  |  DET  |  determiner  |  DT  |  determiner
# year  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# and  |  CCONJ  |  coordinating conjunction  |  CC  |  conjunction, coordinating
# pledges  |  NOUN  |  noun  |  NNS  |  noun, plural
# of  |  ADP  |  adposition  |  IN  |  conjunction, subordinating or preposition
# more  |  ADJ  |  adjective  |  JJR  |  adjective, comparative
# until  |  SCONJ  |  subordinating conjunction  |  IN  |  conjunction, subordinating or preposition
# inflation  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# comes  |  VERB  |  verb  |  VBZ  |  verb, 3rd person singular present
# down  |  ADP  |  adposition  |  RP  |  adverb, particle
# to  |  ADP  |  adposition  |  IN  |  conjunction, subordinating or preposition
# the  |  DET  |  determiner  |  DT  |  determiner
# central  |  ADJ  |  adjective  |  JJ  |  adjective (English), other noun-modifier (Chinese)
# bank  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# ’s  |  PART  |  particle  |  POS  |  possessive ending
# 2  |  NUM  |  numeral  |  CD  |  cardinal number
# %  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# goal  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# .  |  PUNCT  |  punctuation  |  .  |  punctuation mark, sentence closer
# However  |  ADV  |  adverb  |  RB  |  adverb
# ,  |  PUNCT  |  punctuation  |  ,  |  punctuation mark, comma
# Wednesday  |  PROPN  |  proper noun  |  NNP  |  noun, proper singular
# ’s  |  PART  |  particle  |  POS  |  possessive ending
# data  |  NOUN  |  noun  |  NNS  |  noun, plural
# shows  |  VERB  |  verb  |  VBZ  |  verb, 3rd person singular present
# that  |  SCONJ  |  subordinating conjunction  |  IN  |  conjunction, subordinating or preposition
# the  |  DET  |  determiner  |  DT  |  determiner
# Fed  |  PROPN  |  proper noun  |  NNP  |  noun, proper singular
# has  |  VERB  |  verb  |  VBZ  |  verb, 3rd person singular present
# a  |  DET  |  determiner  |  DT  |  determiner
# big  |  ADJ  |  adjective  |  JJ  |  adjective (English), other noun-modifier (Chinese)
# job  |  NOUN  |  noun  |  NN  |  noun, singular or mass
# ahead  |  ADV  |  adverb  |  RB  |  adverb
# .  |  PUNCT  |  punctuation  |  .  |  punctuation mark, sentence closer
#
#
#   |  SPACE  |  space  |  _SP  |  whitespace
# Credits  |  NOUN  |  noun  |  NNS  |  noun, plural
# :  |  PUNCT  |  punctuation  |  :  |  punctuation mark, colon or ellipsis
# cnbc.com  |  X  |  other  |  ADD  |  email

# %%
counts = doc.count_by(spacy.attrs.POS)
counts
# Out:
# {92: 96,
#  100: 27,
#  86: 15,
#  85: 39,
#  96: 16,
#  97: 32,
#  90: 34,
#  95: 4,
#  87: 13,
#  89: 10,
#  84: 23,
#  103: 7,
#  93: 19,
#  94: 4,
#  98: 8,
#  101: 1}

# %%
doc.vocab[92].text
# Out:
# 'NOUN'

# %%
for k, v in counts.items():
    print(doc.vocab[k].text, "|", v)
# Out:
# NOUN | 96
# VERB | 27
# ADV | 15
# ADP | 39
# PROPN | 16
# PUNCT | 32
# DET | 34
# PRON | 4
# AUX | 13
# CCONJ | 10
# ADJ | 23
# SPACE | 7
# NUM | 19
# PART | 4
# SCONJ | 8
# X | 1

# %%
for ent in doc.ents:
    print(ent.text, ent.label_, spacy.explain(ent.label_), sep='|')
# Out:
# April|DATE|Absolute or relative dates or periods
# the Bureau of Labor Statistics|ORG|Companies, agencies, institutions, etc.
# Wednesday|DATE|Absolute or relative dates or periods
# 8.3%|PERCENT|Percentage, including "%"
# a year ago|DATE|Absolute or relative dates or periods
# Dow Jones|ORG|Companies, agencies, institutions, etc.
# 8.1%|PERCENT|Percentage, including "%"
# March|DATE|Absolute or relative dates or periods
# the summer of 1982|DATE|Absolute or relative dates or periods
# 6.2%|PERCENT|Percentage, including "%"
# 6%|PERCENT|Percentage, including "%"
# March|DATE|Absolute or relative dates or periods
# 0.3%|PERCENT|Percentage, including "%"
# 0.2%|PERCENT|Percentage, including "%"
# 0.6%|PERCENT|Percentage, including "%"
# 0.4%|PERCENT|Percentage, including "%"
# 0.1%|PERCENT|Percentage, including "%"
# the month|DATE|Absolute or relative dates or periods
# 0.3%|PERCENT|Percentage, including "%"
# hourly|TIME|Times smaller than a day
# the past year|DATE|Absolute or relative dates or periods
# 2.6%|PERCENT|Percentage, including "%"
# hourly|TIME|Times smaller than a day
# 5.5%|PERCENT|Percentage, including "%"
# Covid|NORP|Nationalities or religious or political groups
# 2021|DATE|Absolute or relative dates or periods
# 1984|DATE|Absolute or relative dates or periods
# one|CARDINAL|Numerals that do not fall under another type
# two|CARDINAL|Numerals that do not fall under another type
# Federal Reserve|ORG|Companies, agencies, institutions, etc.
# two|CARDINAL|Numerals that do not fall under another type
# this year|DATE|Absolute or relative dates or periods
# 2%|PERCENT|Percentage, including "%"
# Wednesday|DATE|Absolute or relative dates or periods
# Fed|ORG|Companies, agencies, institutions, etc.

# %%
displacy.render(doc)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="0191217ff4414f3b9527de7950533b77-0" class="displacy" width="53075" height="749.5" direction="ltr" style="max-width: none; height: 749.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">Inflation</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">rose</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">again</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">April,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">continuing</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="1275">climb</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="1450">that</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="1625">has</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="1800">pushed</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="1975">consumers</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="2150">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="2325">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="2500">brink</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="2675">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="2850">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="3025">threatening</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="3200">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="3375">economic</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="3550">expansion,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="3725">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="3900">Bureau</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="4075">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="4250">Labor</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="4425">Statistics</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="4600">reported</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="4775">Wednesday.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="4950">
#
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="5125">The</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="5300">consumer</tspan>
#     <tspan class="displacy-tag" dy="

# %%
displacy.render(doc, style="ent")
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Inflation rose again in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     April
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , continuing a climb that has pushed consumers to the brink and is threatening the economic expansion,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Bureau of Labor Statistics
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  reported
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wednesday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# .<br><br>The consumer price index, a broad-based measure of prices for goods and services, increased
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     8.3%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
#  from
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     a year ago
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , higher than the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Dow Jones
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  estimate for an
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     8.1%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
#  gain. That represented a slight ease from
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     March
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ’s peak but was still close to the highest level since
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the summer of 1982
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# .<br><br>Removing volatile food and energy prices, so-called core CPI still rose
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     6.2%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
# , against expectations for a
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     6%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
#  gain, clouding hopes that inflation had peaked in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     March
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# .<br><br>The month-over-month gains also were higher than expectations —
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     0.3%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
#  on headline CPI versus the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     0.2%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
#  estimate and a
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     0.6%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
#  increase for core, against the outlook for a
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     0.4%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
#  gain.<br><br>The price gains also meant that workers continued to lose ground. Real wages adjusted for inflation decreased
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     0.1%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
#  on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the month
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  despite a nominal increase of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     0.3%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
#  in average
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     hourly
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#  earnings. Over
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the past year
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , real earnings have dropped
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2.6%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
#  even though average
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     hourly
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</s

# %%
nlp.pipe_labels['ner']
# Out:
# ['CARDINAL',
#  'DATE',
#  'EVENT',
#  'FAC',
#  'GPE',
#  'LANGUAGE',
#  'LAW',
#  'LOC',
#  'MONEY',
#  'NORP',
#  'ORDINAL',
#  'ORG',
#  'PERCENT',
#  'PERSON',
#  'PRODUCT',
#  'QUANTITY',
#  'TIME',
#  'WORK_OF_ART']

# %%
from spacy.lang.en.stop_words import STOP_WORDS

STOP_WORDS
# Out:
# {"'d",
#  "'ll",
#  "'m",
#  "'re",
#  "'s",
#  "'ve",
#  'a',
#  'about',
#  'above',
#  'across',
#  'after',
#  'afterwards',
#  'again',
#  'against',
#  'all',
#  'almost',
#  'alone',
#  'along',
#  'already',
#  'also',
#  'although',
#  'always',
#  'am',
#  'among',
#  'amongst',
#  'amount',
#  'an',
#  'and',
#  'another',
#  'any',
#  'anyhow',
#  'anyone',
#  'anything',
#  'anyway',
#  'anywhere',
#  'are',
#  'around',
#  'as',
#  'at',
#  'back',
#  'be',
#  'became',
#  'because',
#  'become',
#  'becomes',
#  'becoming',
#  'been',
#  'before',
#  'beforehand',
#  'behind',
#  'being',
#  'below',
#  'beside',
#  'besides',
#  'between',
#  'beyond',
#  'both',
#  'bottom',
#  'but',
#  'by',
#  'ca',
#  'call',
#  'can',
#  'cannot',
#  'could',
#  'did',
#  'do',
#  'does',
#  'doing',
#  'done',
#  'down',
#  'due',
#  'during',
#  'each',
#  'eight',
#  'either',
#  'eleven',
#  'else',
#  'elsewhere',
#  'empty',
#  'enough',
#  'even',
#  'ever',
#  'every',
#  'everyone',
#  'everything',
#  'everywhere',
#  'except',
#  'few',
#  'fifteen',
#  'fifty',
#  'first',
#  'five',
#  'for',
#  'former',
#  'formerly',
#  'forty',
#  'four',
#  'from',
#  'front',
#  'full',
#  'further',
#  'get',
#  'give',
#  'go',
#  'had',
#  'has',
#  'have',
#  'he',
#  'hence',
#  'her',
#  'here',
#  'hereafter',
#  'hereby',
#  'herein',
#  'hereupon',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'however',
#  'hundred',
#  'i',
#  'if',
#  'in',
#  'indeed',
#  'into',
#  'is',
#  'it',
#  'its',
#  'itself',
#  'just',
#  'keep',
#  'last',
#  'latter',
#  'latterly',
#  'least',
#  'less',
#  'made',
#  'make',
#  'many',
#  'may',
#  'me',
#  'meanwhile',
#  'might',
#  'mine',
#  'more',
#  'moreover',
#  'most',
#  'mostly',
#  'move',
#  'much',
#  'must',
#  'my',
#  'myself',
#  "n't",
#  'name',
#  'namely',
#  'neither',
#  'never',
#  'nevertheless',
#  'next',
#  'nine',
#  'no',
#  'nobody',
#  'none',
#  'noone',
#  'nor',
#  'not',
#  'nothing',
#  'now',
#  'nowhere',
#  'n‘t',
#  'n’t',
#  'of',
#  'off',
#  'often',
#  'on',
#  'once',
#  'one',
#  'only',
#  'onto',
#  'or',
#  'other',
#  'others',
#  'otherwise',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  'part',
#  'per',
#  'perhaps',
#  'please',
#  'put',
#  'quite',
#  'rather',
#  're',
#  'really',
#  'regarding',
#  'same',
#  'say',
#  'see',
#  'seem',
#  'seemed',
#  'seeming',
#  'seems',
#  'serious',
#  'several',
#  'she',
#  'should',
#  'show',
#  'side',
#  'since',
#  'six',
#  'sixty',
#  'so',
#  'some',
#  'somehow',
#  'someone',
#  'something',
#  'sometime',
#  'sometimes',
#  'somewhere',
#  'still',
#  'such',
#  'take',
#  'ten',
#  'than',
#  'that',
#  'the',
#  'their',
#  'them',
#  'themselves',
#  'then',
#  'thence',
#  'there',
#  'thereafter',
#  'thereby',
#  'therefore',
#  'therein',
#  'thereupon',
#  'these',
#  'they',
#  'third',
#  'this',
#  'those',
#  'though',
#  'three',
#  'through',
#  'throughout',
#  'thru',
#  'thus',
#  'to',
#  'together',
#  'too',
#  'top',
#  'toward',
#  'towards',
#  'twelve',
#  'twenty',
#  'two',
#  'under',
#  'unless',
#  'until',
#  'up',
#  'upon',
#  'us',
#  'used',
#  'using',
#  'various',
#  'very',
#  'via',
#  'was',
#  'we',
#  'well',
#  'were',
#  'what',
#  'whatever',
#  'when',
#  'whence',
#  'whenever',
#  'where',
#  'whereafter',
#  'whereas',
#  'whereby',
#  'wherein',
#  'whereupon',
#  'wherever',
#  'whether',
#  'which',
#  'while',
#  'whither',
#  'who',
#  'whoever',
#  'whole',
#  'whom',
#  'whose',
#  'why',
#  'will',
#  'with',
#  'within',
#  'without',
#  'would',
#  'yet',
#  'you',
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  '‘d',
#  '‘ll',
#  '‘m',
#  '‘re',
#  '‘s',
#  '‘ve',
#  '’d',
#  '’ll',
#  '’m',
#  '’re',
#  '’s',
#  '’ve'}

# %%
nlp = spacy.load('en_core_web_sm')
doc = nlp(text)
doc
# Out:
# Look for data to help you address the question. Governments are good
# sources because data from public research is often freely available. Good
# places to start include http://www.data.gov/, and http://www.science.
# gov/, and in the United Kingdom, http://data.gov.uk/.
# Two of my favorite data sets are the General Social Survey at http://www3.norc.org/gss+website/,
# and the European Social Survey at http://www.europeansocialsurvey.org/.

# %%
for token in doc:
    if token.is_stop:
        print(token)
# Out:
# for
# to
# you
# the
# are
# because
# from
# is
# often
# to
# and
# and
# in
# the
# Two
# of
# my
# are
# the
# at
# and
# the
# at

# %%
def preprocess(text):
    doc = nlp(text)

    no_stop_words = [token.text for token in doc if not token.is_stop and not token.is_punct]
    return no_stop_words

# %%
preprocess(text)
# Out:
# ['\n',
#  'Look',
#  'data',
#  'help',
#  'address',
#  'question',
#  'Governments',
#  'good',
#  '\n',
#  'sources',
#  'data',
#  'public',
#  'research',
#  'freely',
#  'available',
#  'Good',
#  '\n',
#  'places',
#  'start',
#  'include',
#  'http://www.data.gov/',
#  'http://www.science',
#  '\n',
#  'gov/',
#  'United',
#  'Kingdom',
#  'http://data.gov.uk/.',
#  '\n',
#  'favorite',
#  'data',
#  'sets',
#  'General',
#  'Social',
#  'Survey',
#  'http://www3.norc.org/gss+website/',
#  '\n',
#  'European',
#  'Social',
#  'Survey',
#  'http://www.europeansocialsurvey.org/.',
#  '\n']
